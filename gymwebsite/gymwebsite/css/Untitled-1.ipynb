# %%
.container {
    flex: flex;
    align-items: center;
    height: 100px;
}

.gymPic {
    width: 1450px;
    height: 520px;
    background-size: conatin;
}
.header {
    margin: 0 auto;
    color: white;
    right: 50%;
    padding-left: 20px;
    margin-top: 270px;
    font-size: large;
    width: 300px;
}

.wrapper {
    display: flex;
    flex-wrap: wrap;
    justify-content: center;
    margin-top: 150px;
    gap: 20px;
}



.dublin {width: 300px;
    height: 300px; 
    background-color: red;
    border: 30px;
    color: white;
    outline: 2px solid black;
    text-align: center;



    *{
    margin: 0;
    padding: 0;
}


.grid {
    display: grid;
    grid-template-columns: 1fr 1 frr 1fr;
    grid-template-rows: 1fr 1fr 1fr;
    grid-template-areas: 
    "containertop containertop containertop"
    "DublinImagecontainer Cork Galway"
    "Limerick Clare Wexford";
    grid-gap: 10px;
}
.containertop {
    grid-area: containertop;
}

.containertop Img {
    width: 100%;
    height: 600px;
    background-size: conatin;
    
}
.header {
    position: absolute;
    top: 450px;
    left: 40%;
    color: white;
    padding: 10px;
    font-size: large;
}

.overlapwriting {
    position: absolute;
    width: 212.07px;
    height: 346.42px;
    line-height: 2.0;
    color: white;
    padding: 10px;
    top: 50%;
    left: 50%;
    transform: translate(-50%, -50%);
    font-size:larger;
    text-align: center;
    box-sizing: border-box;
    display: flex;
    justify-content: center;
    align-items: center;
    flex-direction: column;
    max-width: fit-content;
}

.DublinImagecontainer {
    grid-area: DublinImagecontainer;
    padding-left: 40px;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    position:sticky;
    margin-top: 50px;
    box-shadow: 10px 10px 30px black; 
}

.DublinImagecontainer Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}


.Dublin h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Dublin p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Dublin h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}


.Cork {
    grid-area: Cork;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    margin-top: 50px;
    position: sticky;
    box-shadow: 10px 10px 30px black;
}
.Cork Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}
.Cork h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Cork p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Cork h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}

.Galway {
    grid-area: Galway;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    margin-top: 50px;
    position: sticky;
    box-shadow: 10px 10px 30px black;
}
.Galway Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}
.Galway h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Galway p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Galway h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}

.Limerick {
    grid-area: Limerick;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    position: sticky;
    box-shadow: 10px 10px 30px black;
}
.Limerick Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}
.Limerick h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Limerick p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Limerick h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}

.Clare {
    grid-area: Clare;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    position: sticky;
    box-shadow: 10px 10px 30px black;
}
.Clare Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}
.Clare h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Clare p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Clare h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}

.Wexford {
    grid-area: Wexford;
    width: 350px;
    height: 400px; 
    background-color: orange;
    border: 30px;
    padding: 15px;
    color: white;
    outline: 2px solid black;
    margin-left: 50px;
    position: sticky;
    box-shadow: 10px 10px 30px black;
}
.Wexford Img {
    width: 100%;
    height: 100%;
    object-fit: cover;
}

.Wexford h1 {
    font-family:Arial, Helvetica, sans-serif;
    text-align: center;
}
.Wexford p {
    font-family: Georgia, 'Times New Roman', Times, serif;
    text-align: center;
}
.Wexford h2 {
    font-family:'Times New Roman', Times, serif;
    text-align: center;
}



@media screen and (min-width: 736px)
{
    .grid {
        display: grid;
        grid-template-columns: 1fr 1 frr 1fr;
        grid-template-rows: 1fr 1fr 1fr;
        grid-template-areas: 
        "containertop containertop containertop"
        "DublinImagecontainer Cork Galway"
        "Limerick Clare Wexford"; 
    }
}




 // make the showError function 

    function showError(errorElement, errorMessage){
        // target error element with query selector 
        document.querySelector("." + errorElement).classList.add("display-error");
        document.querySelector("."+ errorElement).innerHTML = errorMessage;


    }


    // create a function to hide the error elements to set error to default state when the form is submitted 
    
    // use query selector to target all error elements 
    // query selectorAll to return an array which holds the error elements 


    // next: loop through error arrays and remove display class from the error elements


    function hideError(){
        let errors = document.querySelectorAll(".error");
        for(let error of errors){
            error.classList.remove("display-error");
        }
    }


    // create a check for the input fields 
    // get access to the form element, by targeting the form by it's name attribute 
   let form = document.forms['sendMessage'];
   // assign onsubmit eventlistenenr 
   form.onsubmit = function (event){

    hideError();

    if(form.firstName.value ===""){
    showError("firstName error", "Please provide you first Name");
    return false;
    }
        
    } 


@media (max-width: 700px){
    #grid {
        width: calc (50% - 2rem);
    }
}
@media (max-width: 500px){
    #grid {
        width: 100%;
    }
}







<div class="message">
    <h1> Send us a message!</h1>
    <form>
    <input required type="text" class="input" placeholder="First Name">
    <!-- create class error for the inputs that contain error message-->
    <div class="error"></div>
    <input required type="text" class="input" placeholder="Last Name">
    <input required type="text" class="input" placeholder="phonenumber">
    <input required type="text" class="input" placeholder="email address">
    <input required type="text" class="input" placeholder="Subject">
    <textarea type="text" class="message-field" placeholder="Your message..."></textarea>
    <!-- call the pop up by calling the function messageSent()-->
    <button type="button" class="button" onclick="messageSent()">submit</button>
    <!-- error handling, do this tomorrow 
    <span class="error-display">
        <i class="fa-thin fa-circle-exclamation"></i>
        </span>
    <span class="success-display">
        <i class="fa-thin fa-check"></i>
        </span>   
        <div class="error text-red"></div> --> 
        <div class="pop-up" id="messageSentPopUp">
            <p> Thank you! Your message has been sent</p>
            <button type="button" onclick="closePopup()">Ok</button>
        </div>
    </form>
</div>





<!-- Javascript-->

<!-- define the functions messageSent -->

<!-- define the variable, then get the Id from the document (the code above) -->
<!-- define the functions closePopup -->





<script type="text/javascript">
let popUp = document.getElementById("messageSentPopUp");

    function messageSent(){
        popUp.classList.add("open-PopUp");
    }
    function closePopup(){
        popUp.classList.remove("open-PopUp");
    }

</script>





<form id="messageform">
    <div class="inputCont">
        <label>Name</label>        
        <input type="text" class="input" placeholder="Please enter your First Name" id="customer-name" onkeyup="validateName()">
        <span id="name-error"></span>
    </div>
    <div class="input-cont">
        <label>Phonenumber</label>   
        <input type="phone" class="input" placeholder="phonenumber" id="phone-number" onkeyup="validatePhone()">
        <span id="phone-error"></span>
    </div>
    <div class="input-cont">
        <label>Email</label>
        <input type="email" class="input" placeholder="email address">
        <span id="email-error"></span>
    </div>
    <div class="input-cont">    
        <label>Subject</label>
        <input type="text" class="input" placeholder="Subject">
        <span id="subject-error"></span>
    </div>    
    <div class="input-cont">
        <label>Message</label>
        <textarea type="text" class="message-field" placeholder="Your message..."></textarea>
        <span id="message-error"></span>
    </div>
    <!-- call the pop up by calling the function messageSent()-->
    <button>Submit </button>
    <span id="submit-eror"></span>
</div>
</form>
